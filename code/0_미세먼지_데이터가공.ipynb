# %%
import pandas as pd

# %%
dust_201804= pd.read_csv('../외부데이터/미세먼지_raw/201804_미세먼지.CSV',encoding='euc-kr')
dust_201804 = dust_201804.drop([0], axis=0)
dust_201804= dust_201804.drop([7], axis=0)
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.set_index(1)
dust_201804 = dust_201804.drop(['측정망'], axis=0)
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.set_index('측정소명')
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.reset_index()
dust_201804['날짜']='2018년 4월'+dust_201804[1]
dust_201804=dust_201804[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201804=dust_201804.set_index('날짜')

# %%
dust_201805= pd.read_csv('../외부데이터/미세먼지_raw/201805_미세먼지.CSV',encoding='euc-kr')
dust_201805 = dust_201805.drop([0], axis=0)
dust_201805= dust_201805.drop([7], axis=0)
dust_201805=dust_201805.transpose()
dust_201805=dust_201805.set_index(1)
dust_201805 = dust_201805.drop(['측정망'], axis=0)
dust_201805=dust_201805.transpose()
dust_201805=dust_201805.set_index('측정소명')
dust_201805=dust_201805.transpose()
dust_201805=dust_201805.reset_index()
dust_201805['날짜']='2018년 5월'+dust_201805[1]
dust_201805=dust_201805[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201805=dust_201805.set_index('날짜')

# %%
dust_201806= pd.read_csv('../외부데이터/미세먼지_raw/201806_미세먼지.CSV',encoding='euc-kr')
dust_201806 = dust_201806.drop([0], axis=0)
dust_201806= dust_201806.drop([7], axis=0)
dust_201806=dust_201806.transpose()
dust_201806=dust_201806.set_index(1)
dust_201806 = dust_201806.drop(['측정망'], axis=0)
dust_201806=dust_201806.transpose()
dust_201806=dust_201806.set_index('측정소명')
dust_201806=dust_201806.transpose()
dust_201806=dust_201806.reset_index()
dust_201806['날짜']='2018년 6월'+dust_201806[1]
dust_201806=dust_201806[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201806=dust_201806.set_index('날짜')

# %%
dust_201807= pd.read_csv('../외부데이터/미세먼지_raw/201807_미세먼지.CSV',encoding='euc-kr')
dust_201807 = dust_201807.drop([0], axis=0)
dust_201807= dust_201807.drop([7], axis=0)
dust_201807=dust_201807.transpose()
dust_201807=dust_201807.set_index(1)
dust_201807 = dust_201807.drop(['측정망'], axis=0)
dust_201807=dust_201807.transpose()
dust_201807=dust_201807.set_index('측정소명')
dust_201807=dust_201807.transpose()
dust_201807=dust_201807.reset_index()
dust_201807['날짜']='2018년 7월'+dust_201807[1]
dust_201807=dust_201807[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201807=dust_201807.set_index('날짜')

# %%
dust_201808= pd.read_csv('../외부데이터/미세먼지_raw/201808_미세먼지.CSV',encoding='euc-kr')
dust_201808 = dust_201808.drop([0], axis=0)
dust_201808= dust_201808.drop([7], axis=0)
dust_201808=dust_201808.transpose()
dust_201808=dust_201808.set_index(1)
dust_201808 = dust_201808.drop(['측정망'], axis=0)
dust_201808=dust_201808.transpose()
dust_201808=dust_201808.set_index('측정소명')
dust_201808=dust_201808.transpose()
dust_201808=dust_201808.reset_index()
dust_201808['날짜']='2018년 8월'+dust_201808[1]
dust_201808=dust_201808[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201808=dust_201808.set_index('날짜')

# %%
dust_201809= pd.read_csv('../외부데이터/미세먼지_raw/201809_미세먼지.CSV',encoding='euc-kr')
dust_201809 = dust_201809.drop([0], axis=0)
dust_201809= dust_201809.drop([7], axis=0)
dust_201809=dust_201809.transpose()
dust_201809=dust_201809.set_index(1)
dust_201809 = dust_201809.drop(['측정망'], axis=0)
dust_201809=dust_201809.transpose()
dust_201809=dust_201809.set_index('측정소명')
dust_201809=dust_201809.transpose()
dust_201809=dust_201809.reset_index()
dust_201809['날짜']='2018년 9월'+dust_201809[1]
dust_201809=dust_201809[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201809=dust_201809.set_index('날짜')

# %%
dust_201810= pd.read_csv('../외부데이터/미세먼지_raw/201810_미세먼지.CSV',encoding='euc-kr')
dust_201810 = dust_201810.drop([0], axis=0)
dust_201810= dust_201810.drop([7], axis=0)
dust_201810=dust_201810.transpose()
dust_201810=dust_201810.set_index(1)
dust_201810 = dust_201810.drop(['측정망'], axis=0)
dust_201810=dust_201810.transpose()
dust_201810=dust_201810.set_index('측정소명')
dust_201810=dust_201810.transpose()
dust_201810=dust_201810.reset_index()
dust_201810['날짜']='2018년 10월'+dust_201810[1]
dust_201810=dust_201810[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201810=dust_201810.set_index('날짜')

# %%
dust_201811= pd.read_csv('../외부데이터/미세먼지_raw/201811_미세먼지.CSV',encoding='euc-kr')
dust_201811 = dust_201811.drop([0], axis=0)
dust_201811= dust_201811.drop([7], axis=0)
dust_201811=dust_201811.transpose()
dust_201811=dust_201811.set_index(1)
dust_201811 = dust_201811.drop(['측정망'], axis=0)
dust_201811=dust_201811.transpose()
dust_201811=dust_201811.set_index('측정소명')
dust_201811=dust_201811.transpose()
dust_201811=dust_201811.reset_index()
dust_201811['날짜']='2018년 11월'+dust_201811[1]
dust_201811=dust_201811[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201811=dust_201811.set_index('날짜')

# %%
dust_201812= pd.read_csv('../외부데이터/미세먼지_raw/201812_미세먼지.CSV',encoding='euc-kr')
dust_201812 = dust_201812.drop([0], axis=0)
dust_201812= dust_201812.drop([7], axis=0)
dust_201812=dust_201812.transpose()
dust_201812=dust_201812.set_index(1)
dust_201812 = dust_201812.drop(['측정망'], axis=0)
dust_201812=dust_201812.transpose()
dust_201812=dust_201812.set_index('측정소명')
dust_201812=dust_201812.transpose()
dust_201812=dust_201812.reset_index()
dust_201812['날짜']='2018년 12월'+dust_201812[1]
dust_201812=dust_201812[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201812=dust_201812.set_index('날짜')

# %%
dust_201901= pd.read_csv('../외부데이터/미세먼지_raw/201901_미세먼지.CSV',encoding='euc-kr')
dust_201901 = dust_201901.drop([0], axis=0)
dust_201901= dust_201901.drop([7], axis=0)
dust_201901=dust_201901.transpose()
dust_201901=dust_201901.set_index(1)
dust_201901 = dust_201901.drop(['측정망'], axis=0)
dust_201901=dust_201901.transpose()
dust_201901=dust_201901.set_index('측정소명')
dust_201901=dust_201901.transpose()
dust_201901=dust_201901.reset_index()
dust_201901['날짜']='2019년 1월'+dust_201901[1]
dust_201901=dust_201901[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201901=dust_201901.set_index('날짜')

# %%
dust_201902= pd.read_csv('../외부데이터/미세먼지_raw/201902_미세먼지.CSV',encoding='euc-kr')
dust_201902 = dust_201902.drop([0], axis=0)
dust_201902= dust_201902.drop([7], axis=0)
dust_201902=dust_201902.transpose()
dust_201902=dust_201902.set_index(1)
dust_201902 = dust_201902.drop(['측정망'], axis=0)
dust_201902=dust_201902.transpose()
dust_201902=dust_201902.set_index('측정소명')
dust_201902=dust_201902.transpose()
dust_201902=dust_201902.reset_index()
dust_201902['날짜']='2019년 2월'+dust_201902[1]
dust_201902=dust_201902[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201902=dust_201902.set_index('날짜')

# %%
dust_201903= pd.read_csv('../외부데이터/미세먼지_raw/201903_미세먼지.CSV',encoding='euc-kr')
dust_201903 = dust_201903.drop([0], axis=0)
dust_201903= dust_201903.drop([7], axis=0)
dust_201903=dust_201903.transpose()
dust_201903=dust_201903.set_index(1)
dust_201903 = dust_201903.drop(['측정망'], axis=0)
dust_201903=dust_201903.transpose()
dust_201903=dust_201903.set_index('측정소명')
dust_201903=dust_201903.transpose()
dust_201903=dust_201903.reset_index()
dust_201903['날짜']='2019년 3월'+dust_201903[1]
dust_201903=dust_201903[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201903=dust_201903.set_index('날짜')

# %%
dust_201904= pd.read_csv('../외부데이터/미세먼지_raw/201904_미세먼지.CSV',encoding='euc-kr')
dust_201904 = dust_201904.drop([0], axis=0)
dust_201904= dust_201904.drop([7], axis=0)
dust_201904=dust_201904.transpose()
dust_201904=dust_201904.set_index(1)
dust_201904 = dust_201904.drop(['측정망'], axis=0)
dust_201904=dust_201904.transpose()
dust_201904=dust_201904.set_index('측정소명')
dust_201904=dust_201904.transpose()
dust_201904=dust_201904.reset_index()
dust_201904['날짜']='2019년 4월'+dust_201904[1]
dust_201904=dust_201904[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201904=dust_201904.set_index('날짜')

# %%
dust_201905= pd.read_csv('../외부데이터/미세먼지_raw/201905_미세먼지.CSV',encoding='euc-kr')
dust_201905 = dust_201905.drop([0], axis=0)
dust_201905= dust_201905.drop([7], axis=0)
dust_201905=dust_201905.transpose()
dust_201905=dust_201905.set_index(1)
dust_201905 = dust_201905.drop(['측정망'], axis=0)
dust_201905=dust_201905.transpose()
dust_201905=dust_201905.set_index('측정소명')
dust_201905=dust_201905.transpose()
dust_201905=dust_201905.reset_index()
dust_201905['날짜']='2019년 5월'+dust_201905[1]
dust_201905=dust_201905[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201905=dust_201905.set_index('날짜')

# %%
dust_201906= pd.read_csv('../외부데이터/미세먼지_raw/201906_미세먼지.CSV',encoding='euc-kr')
dust_201906 = dust_201906.drop([0], axis=0)
dust_201906= dust_201906.drop([7], axis=0)
dust_201906=dust_201906.transpose()
dust_201906=dust_201906.set_index(1)
dust_201906 = dust_201906.drop(['측정망'], axis=0)
dust_201906=dust_201906.transpose()
dust_201906=dust_201906.set_index('측정소명')
dust_201906=dust_201906.transpose()
dust_201906=dust_201906.reset_index()
dust_201906['날짜']='2019년 6월'+dust_201906[1]
dust_201906=dust_201906[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201906=dust_201906.set_index('날짜')

# %%
dust_201907= pd.read_csv('../외부데이터/미세먼지_raw/201907_미세먼지.CSV',encoding='euc-kr')
dust_201907 = dust_201907.drop([0], axis=0)
dust_201907= dust_201907.drop([7], axis=0)
dust_201907=dust_201907.transpose()
dust_201907=dust_201907.set_index(1)
dust_201907 = dust_201907.drop(['측정망'], axis=0)
dust_201907=dust_201907.transpose()
dust_201907=dust_201907.set_index('측정소명')
dust_201907=dust_201907.transpose()
dust_201907=dust_201907.reset_index()
dust_201907['날짜']='2019년 7월'+dust_201907[1]
dust_201907=dust_201907[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201907=dust_201907.set_index('날짜')

# %%
dust_201908= pd.read_csv('../외부데이터/미세먼지_raw/201908_미세먼지.CSV',encoding='euc-kr')
dust_201908 = dust_201908.drop([0], axis=0)
dust_201908= dust_201908.drop([7], axis=0)
dust_201908=dust_201908.transpose()
dust_201908=dust_201908.set_index(1)
dust_201908 = dust_201908.drop(['측정망'], axis=0)
dust_201908=dust_201908.transpose()
dust_201908=dust_201908.set_index('측정소명')
dust_201908=dust_201908.transpose()
dust_201908=dust_201908.reset_index()
dust_201908['날짜']='2019년 8월'+dust_201908[1]
dust_201908=dust_201908[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201908=dust_201908.set_index('날짜')

# %%
dust_201909= pd.read_csv('../외부데이터/미세먼지_raw/201909_미세먼지.CSV',encoding='euc-kr')
dust_201909 = dust_201909.drop([0], axis=0)
dust_201909= dust_201909.drop([7], axis=0)
dust_201909=dust_201909.transpose()
dust_201909=dust_201909.set_index(1)
dust_201909 = dust_201909.drop(['측정망'], axis=0)
dust_201909=dust_201909.transpose()
dust_201909=dust_201909.set_index('측정소명')
dust_201909=dust_201909.transpose()
dust_201909=dust_201909.reset_index()
dust_201909['날짜']='2019년 9월'+dust_201909[1]
dust_201909=dust_201909[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201909=dust_201909.set_index('날짜')

# %%
dust_201910= pd.read_csv('../외부데이터/미세먼지_raw/201910_미세먼지.CSV',encoding='euc-kr')
dust_201910 = dust_201910.drop([0], axis=0)
dust_201910= dust_201910.drop([7], axis=0)
dust_201910=dust_201910.transpose()
dust_201910=dust_201910.set_index(1)
dust_201910 = dust_201910.drop(['측정망'], axis=0)
dust_201910=dust_201910.transpose()
dust_201910=dust_201910.set_index('측정소명')
dust_201910=dust_201910.transpose()
dust_201910=dust_201910.reset_index()
dust_201910['날짜']='2019년 10월'+dust_201910[1]
dust_201910=dust_201910[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201910=dust_201910.set_index('날짜')

# %%
dust_201911= pd.read_csv('../외부데이터/미세먼지_raw/201911_미세먼지.CSV',encoding='euc-kr')
dust_201911 = dust_201911.drop([0], axis=0)
dust_201911= dust_201911.drop([7], axis=0)
dust_201911=dust_201911.transpose()
dust_201911=dust_201911.set_index(1)
dust_201911 = dust_201911.drop(['측정망'], axis=0)
dust_201911=dust_201911.transpose()
dust_201911=dust_201911.set_index('측정소명')
dust_201911=dust_201911.transpose()
dust_201911=dust_201911.reset_index()
dust_201911['날짜']='2019년 11월'+dust_201911[1]
dust_201911=dust_201911[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201911=dust_201911.set_index('날짜')

# %%
dust_201912= pd.read_csv('../외부데이터/미세먼지_raw/201912_미세먼지.CSV',encoding='euc-kr')
dust_201912 = dust_201912.drop([0], axis=0)
dust_201912= dust_201912.drop([7], axis=0)
dust_201912=dust_201912.transpose()
dust_201912=dust_201912.set_index(1)
dust_201912 = dust_201912.drop(['측정망'], axis=0)
dust_201912=dust_201912.transpose()
dust_201912=dust_201912.set_index('측정소명')
dust_201912=dust_201912.transpose()
dust_201912=dust_201912.reset_index()
dust_201912['날짜']='2019년 12월'+dust_201912[1]
dust_201912=dust_201912[['[제주 제주시]고산리','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','날짜']]
dust_201912=dust_201912.set_index('날짜')

# %%
dust_202001= pd.read_csv('../외부데이터/미세먼지_raw/202001_미세먼지.CSV',encoding='euc-kr')
dust_202001 = dust_202001.drop([0], axis=0)
dust_202001= dust_202001.drop([7], axis=0)
dust_202001=dust_202001.transpose()
dust_202001=dust_202001.set_index(1)
dust_202001 = dust_202001.drop(['측정망'], axis=0)
dust_202001=dust_202001.transpose()
dust_202001=dust_202001.set_index('측정소명')
dust_202001=dust_202001.transpose()
dust_202001=dust_202001.reset_index()
dust_202001['날짜']='2020년 1월'+dust_202001[1]
dust_202001=dust_202001[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202001=dust_202001.set_index('날짜')

# %%
dust_202002= pd.read_csv('../외부데이터/미세먼지_raw/202002_미세먼지.CSV',encoding='euc-kr')
dust_202002 = dust_202002.drop([0], axis=0)
dust_202002= dust_202002.drop([7], axis=0)
dust_202002=dust_202002.transpose()
dust_202002=dust_202002.set_index(1)
dust_202002 = dust_202002.drop(['측정망'], axis=0)
dust_202002=dust_202002.transpose()
dust_202002=dust_202002.set_index('측정소명')
dust_202002=dust_202002.transpose()
dust_202002=dust_202002.reset_index()
dust_202002['날짜']='2020년 2월'+dust_202002[1]
dust_202002=dust_202002[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202002=dust_202002.set_index('날짜')

# %%
dust_202003= pd.read_csv('../외부데이터/미세먼지_raw/202003_미세먼지.CSV',encoding='euc-kr')
dust_202003 = dust_202003.drop([0], axis=0)
dust_202003= dust_202003.drop([7], axis=0)
dust_202003=dust_202003.transpose()
dust_202003=dust_202003.set_index(1)
dust_202003 = dust_202003.drop(['측정망'], axis=0)
dust_202003=dust_202003.transpose()
dust_202003=dust_202003.set_index('측정소명')
dust_202003=dust_202003.transpose()
dust_202003=dust_202003.reset_index()
dust_202003['날짜']='2020년 3월'+dust_202003[1]
dust_202003=dust_202003[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202003=dust_202003.set_index('날짜')

# %%
dust_202004= pd.read_csv('../외부데이터/미세먼지_raw/202004_미세먼지.CSV',encoding='euc-kr')
dust_202004 = dust_202004.drop([0], axis=0)
dust_202004= dust_202004.drop([7], axis=0)
dust_202004=dust_202004.transpose()
dust_202004=dust_202004.set_index(1)
dust_202004 = dust_202004.drop(['측정망'], axis=0)
dust_202004=dust_202004.transpose()
dust_202004=dust_202004.set_index('측정소명')
dust_202004=dust_202004.transpose()
dust_202004=dust_202004.reset_index()
dust_202004['날짜']='2020년 4월'+dust_202004[1]
dust_202004=dust_202004[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202004=dust_202004.set_index('날짜')

# %%
dust_202005= pd.read_csv('../외부데이터/미세먼지_raw/202005_미세먼지.CSV',encoding='euc-kr')
dust_202005 = dust_202005.drop([0], axis=0)
dust_202005= dust_202005.drop([7], axis=0)
dust_202005=dust_202005.transpose()
dust_202005=dust_202005.set_index(1)
dust_202005 = dust_202005.drop(['측정망'], axis=0)
dust_202005=dust_202005.transpose()
dust_202005=dust_202005.set_index('측정소명')
dust_202005=dust_202005.transpose()
dust_202005=dust_202005.reset_index()
dust_202005['날짜']='2020년 5월'+dust_202005[1]
dust_202005=dust_202005[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202005=dust_202005.set_index('날짜')

# %%
dust_202006= pd.read_csv('../외부데이터/미세먼지_raw/202006_미세먼지.CSV',encoding='euc-kr')
dust_202006 = dust_202006.drop([0], axis=0)
dust_202006= dust_202006.drop([7], axis=0)
dust_202006=dust_202006.transpose()
dust_202006=dust_202006.set_index(1)
dust_202006 = dust_202006.drop(['측정망'], axis=0)
dust_202006=dust_202006.transpose()
dust_202006=dust_202006.set_index('측정소명')
dust_202006=dust_202006.transpose()
dust_202006=dust_202006.reset_index()
dust_202006['날짜']='2020년 6월'+dust_202006[1]
dust_202006=dust_202006[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202006=dust_202006.set_index('날짜')

# %%
dust_202007= pd.read_csv('../외부데이터/미세먼지_raw/202007_미세먼지.CSV',encoding='euc-kr')
dust_202007 = dust_202007.drop([0], axis=0)
dust_202007= dust_202007.drop([7], axis=0)
dust_202007=dust_202007.transpose()
dust_202007=dust_202007.set_index(1)
dust_202007 = dust_202007.drop(['측정망'], axis=0)
dust_202007=dust_202007.transpose()
dust_202007=dust_202007.set_index('측정소명')
dust_202007=dust_202007.transpose()
dust_202007=dust_202007.reset_index()
dust_202007['날짜']='2020년 7월'+dust_202007[1]
dust_202007=dust_202007[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202007=dust_202007.set_index('날짜')

# %%
dust_202008= pd.read_csv('../외부데이터/미세먼지_raw/202008_미세먼지.CSV',encoding='euc-kr')
dust_202008 = dust_202008.drop([0], axis=0)
dust_202008= dust_202008.drop([7], axis=0)
dust_202008=dust_202008.transpose()
dust_202008=dust_202008.set_index(1)
dust_202008 = dust_202008.drop(['측정망'], axis=0)
dust_202008=dust_202008.transpose()
dust_202008=dust_202008.set_index('측정소명')
dust_202008=dust_202008.transpose()
dust_202008=dust_202008.reset_index()
dust_202008['날짜']='2020년 8월'+dust_202008[1]
dust_202008=dust_202008[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202008=dust_202008.set_index('날짜')

# %%
dust_202009= pd.read_csv('../외부데이터/미세먼지_raw/202009_미세먼지.CSV',encoding='euc-kr')
dust_202009 = dust_202009.drop([0], axis=0)
dust_202009= dust_202009.drop([7], axis=0)
dust_202009=dust_202009.transpose()
dust_202009=dust_202009.set_index(1)
dust_202009 = dust_202009.drop(['측정망'], axis=0)
dust_202009=dust_202009.transpose()
dust_202009=dust_202009.set_index('측정소명')
dust_202009=dust_202009.transpose()
dust_202009=dust_202009.reset_index()
dust_202009['날짜']='2020년 9월'+dust_202009[1]
dust_202009=dust_202009[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202009=dust_202009.set_index('날짜')

# %%
dust_202010= pd.read_csv('../외부데이터/미세먼지_raw/202010_미세먼지.CSV',encoding='euc-kr')
dust_202010 = dust_202010.drop([0], axis=0)
dust_202010= dust_202010.drop([7], axis=0)
dust_202010=dust_202010.transpose()
dust_202010=dust_202010.set_index(1)
dust_202010 = dust_202010.drop(['측정망'], axis=0)
dust_202010=dust_202010.transpose()
dust_202010=dust_202010.set_index('측정소명')
dust_202010=dust_202010.transpose()
dust_202010=dust_202010.reset_index()
dust_202010['날짜']='2020년 10월'+dust_202010[1]
dust_202010=dust_202010[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202010=dust_202010.set_index('날짜')

# %%
dust_202011= pd.read_csv('../외부데이터/미세먼지_raw/202011_미세먼지.CSV',encoding='euc-kr')
dust_202011 = dust_202011.drop([0], axis=0)
dust_202011= dust_202011.drop([7], axis=0)
dust_202011=dust_202011.transpose()
dust_202011=dust_202011.set_index(1)
dust_202011 = dust_202011.drop(['측정망'], axis=0)
dust_202011=dust_202011.transpose()
dust_202011=dust_202011.set_index('측정소명')
dust_202011=dust_202011.transpose()
dust_202011=dust_202011.reset_index()
dust_202011['날짜']='2020년 11월'+dust_202011[1]
dust_202011=dust_202011[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202011=dust_202011.set_index('날짜')

# %%
dust_202012= pd.read_csv('../외부데이터/미세먼지_raw/202012_미세먼지.CSV',encoding='euc-kr')
dust_202012 = dust_202012.drop([0], axis=0)
dust_202012= dust_202012.drop([7], axis=0)
dust_202012=dust_202012.transpose()
dust_202012=dust_202012.set_index(1)
dust_202012 = dust_202012.drop(['측정망'], axis=0)
dust_202012=dust_202012.transpose()
dust_202012=dust_202012.set_index('측정소명')
dust_202012=dust_202012.transpose()
dust_202012=dust_202012.reset_index()
dust_202012['날짜']='2020년 12월'+dust_202012[1]
dust_202012=dust_202012[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202012=dust_202012.set_index('날짜')

# %%
dust_202101= pd.read_csv('../외부데이터/미세먼지_raw/202101_미세먼지.CSV',encoding='euc-kr')
dust_202101 = dust_202101.drop([0], axis=0)
dust_202101= dust_202101.drop([7], axis=0)
dust_202101=dust_202101.transpose()
dust_202101=dust_202101.set_index(1)
dust_202101 = dust_202101.drop(['측정망'], axis=0)
dust_202101=dust_202101.transpose()
dust_202101=dust_202101.set_index('측정소명')
dust_202101=dust_202101.transpose()
dust_202101=dust_202101.reset_index()
dust_202101['날짜']='2021년 1월'+dust_202101[1]
dust_202101=dust_202101[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202101=dust_202101.set_index('날짜')

# %%
dust_202102= pd.read_csv('../외부데이터/미세먼지_raw/202102_미세먼지.CSV',encoding='euc-kr')
dust_202102 = dust_202102.drop([0], axis=0)
dust_202102= dust_202102.drop([7], axis=0)
dust_202102=dust_202102.transpose()
dust_202102=dust_202102.set_index(1)
dust_202102 = dust_202102.drop(['측정망'], axis=0)
dust_202102=dust_202102.transpose()
dust_202102=dust_202102.set_index('측정소명')
dust_202102=dust_202102.transpose()
dust_202102=dust_202102.reset_index()
dust_202102['날짜']='2021년 2월'+dust_202102[1]
dust_202102=dust_202102[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202102=dust_202102.set_index('날짜')

# %%
dust_202103= pd.read_csv('../외부데이터/미세먼지_raw/202103_미세먼지.CSV',encoding='euc-kr')
dust_202103 = dust_202103.drop([0], axis=0)
dust_202103= dust_202103.drop([7], axis=0)
dust_202103=dust_202103.transpose()
dust_202103=dust_202103.set_index(1)
dust_202103 = dust_202103.drop(['측정망'], axis=0)
dust_202103=dust_202103.transpose()
dust_202103=dust_202103.set_index('측정소명')
dust_202103=dust_202103.transpose()
dust_202103=dust_202103.reset_index()
dust_202103['날짜']='2021년 3월'+dust_202103[1]
dust_202103=dust_202103[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202103=dust_202103.set_index('날짜')

# %%
dust_202104= pd.read_csv('../외부데이터/미세먼지_raw/202104_미세먼지.CSV',encoding='euc-kr')
dust_202104 = dust_202104.drop([0], axis=0)
dust_202104= dust_202104.drop([7], axis=0)
dust_202104=dust_202104.transpose()
dust_202104=dust_202104.set_index(1)
dust_202104 = dust_202104.drop(['측정망'], axis=0)
dust_202104=dust_202104.transpose()
dust_202104=dust_202104.set_index('측정소명')
dust_202104=dust_202104.transpose()
dust_202104=dust_202104.reset_index()
dust_202104['날짜']='2021년 4월'+dust_202104[1]
dust_202104=dust_202104[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202104=dust_202104.set_index('날짜')

# %%
dust_202105= pd.read_csv('../외부데이터/미세먼지_raw/202105_미세먼지.CSV',encoding='euc-kr')
dust_202105 = dust_202105.drop([0], axis=0)
dust_202105= dust_202105.drop([7], axis=0)
dust_202105=dust_202105.transpose()
dust_202105=dust_202105.set_index(1)
dust_202105 = dust_202105.drop(['측정망'], axis=0)
dust_202105=dust_202105.transpose()
dust_202105=dust_202105.set_index('측정소명')
dust_202105=dust_202105.transpose()
dust_202105=dust_202105.reset_index()
dust_202105['날짜']='2021년 5월'+dust_202105[1]
dust_202105=dust_202105[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202105=dust_202105.set_index('날짜')

# %%
dust_202106= pd.read_csv('../외부데이터/미세먼지_raw/202106_미세먼지.CSV',encoding='euc-kr')
dust_202106 = dust_202106.drop([0], axis=0)
dust_202106= dust_202106.drop([7], axis=0)
dust_202106=dust_202106.transpose()
dust_202106=dust_202106.set_index(1)
dust_202106 = dust_202106.drop(['측정망'], axis=0)
dust_202106=dust_202106.transpose()
dust_202106=dust_202106.set_index('측정소명')
dust_202106=dust_202106.transpose()
dust_202106=dust_202106.reset_index()
dust_202106['날짜']='2021년 6월'+dust_202106[1]
dust_202106=dust_202106[['[제주 제주시]고산리','[제주 서귀포시]남원읍','[제주 서귀포시]대정읍','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]이도동','[제주 제주시]노형로','날짜']]
dust_202106=dust_202106.set_index('날짜')

# %%
dust_201804= pd.read_csv('../외부데이터/미세먼지_raw/201804_미세먼지.CSV',encoding='euc-kr')
dust_201804 = dust_201804.drop([0], axis=0)
dust_201804= dust_201804.drop([7], axis=0)
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.set_index(1)
dust_201804 = dust_201804.drop(['측정망'], axis=0)
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.set_index('측정소명')
dust_201804=dust_201804.transpose()
dust_201804=dust_201804.reset_index()
dust_201804['날짜']='2018년 4월'+dust_201804[1]
dust_201804=dust_201804[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','[제주 제주시]연동','[제주 제주시]이도동','날짜']]
dust_201804=dust_201804.set_index('날짜')


dust_201804=dust_201804[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]

# %%
dust_201804=dust_201804[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201804['[제주 제주시]고산리']=dust_201804['[제주 제주시]고산리'].astype(int)
dust_201804['[제주 서귀포시]동홍동']=dust_201804['[제주 서귀포시]동홍동'].astype(int)
dust_201804['[제주 서귀포시]성산읍']=dust_201804['[제주 서귀포시]성산읍'].astype(int)
dust_201804['평균']=(dust_201804['[제주 서귀포시]성산읍']+dust_201804['[제주 서귀포시]동홍동']+dust_201804['[제주 제주시]고산리'])/3
dust_201804=dust_201804[['평균']]
dust_201804

# %%
dust_201805=dust_201805[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201805=dust_201805.fillna(0)
dust_201805['[제주 서귀포시]동홍동']=dust_201805['[제주 서귀포시]동홍동'].astype(int)
dust_201805['[제주 서귀포시]성산읍']=dust_201805['[제주 서귀포시]성산읍'].astype(int)
dust_201805['[제주 제주시]고산리']=dust_201805['[제주 제주시]고산리'].astype(int)
dust_201805=dust_201805.reset_index()
dust_201805.loc[12,'[제주 제주시]고산리']=(dust_201805.loc[12,'[제주 서귀포시]동홍동']+dust_201805.loc[12,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[19,'[제주 제주시]고산리']=(dust_201805.loc[19,'[제주 서귀포시]동홍동']+dust_201805.loc[19,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[20,'[제주 제주시]고산리']=(dust_201805.loc[20,'[제주 서귀포시]동홍동']+dust_201805.loc[20,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[21,'[제주 제주시]고산리']=(dust_201805.loc[21,'[제주 서귀포시]동홍동']+dust_201805.loc[21,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[22,'[제주 제주시]고산리']=(dust_201805.loc[22,'[제주 서귀포시]동홍동']+dust_201805.loc[22,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[23,'[제주 제주시]고산리']=(dust_201805.loc[23,'[제주 서귀포시]동홍동']+dust_201805.loc[23,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[24,'[제주 제주시]고산리']=(dust_201805.loc[24,'[제주 서귀포시]동홍동']+dust_201805.loc[24,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[25,'[제주 제주시]고산리']=(dust_201805.loc[25,'[제주 서귀포시]동홍동']+dust_201805.loc[25,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[26,'[제주 제주시]고산리']=(dust_201805.loc[26,'[제주 서귀포시]동홍동']+dust_201805.loc[26,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[27,'[제주 제주시]고산리']=(dust_201805.loc[27,'[제주 서귀포시]동홍동']+dust_201805.loc[27,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[28,'[제주 제주시]고산리']=(dust_201805.loc[28,'[제주 서귀포시]동홍동']+dust_201805.loc[28,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[29,'[제주 제주시]고산리']=(dust_201805.loc[29,'[제주 서귀포시]동홍동']+dust_201805.loc[29,'[제주 서귀포시]성산읍'])/2
dust_201805.loc[30,'[제주 제주시]고산리']=(dust_201805.loc[30,'[제주 서귀포시]동홍동']+dust_201805.loc[30,'[제주 서귀포시]성산읍'])/2
dust_201805['[제주 제주시]고산리']=dust_201805['[제주 제주시]고산리'].astype(int)
dust_201805['[제주 서귀포시]동홍동']=dust_201805['[제주 서귀포시]동홍동'].astype(int)
dust_201805['[제주 서귀포시]성산읍']=dust_201805['[제주 서귀포시]성산읍'].astype(int)
dust_201805['평균']=(dust_201805['[제주 서귀포시]성산읍']+dust_201805['[제주 서귀포시]동홍동']+dust_201805['[제주 제주시]고산리'])/3
dust_201805=dust_201805.set_index('날짜')
dust_201805=dust_201805[['평균']]
dust_201805

# %%
dust_201806=dust_201806[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201806=dust_201806[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201806=dust_201806.fillna(0)
dust_201806['[제주 서귀포시]동홍동']=dust_201806['[제주 서귀포시]동홍동'].astype(int)
dust_201806['[제주 서귀포시]성산읍']=dust_201806['[제주 서귀포시]성산읍'].astype(int)
dust_201806['[제주 제주시]고산리']=dust_201806['[제주 제주시]고산리'].astype(int)
dust_201806=dust_201806.reset_index()

# %%
dust_201806['평균']=(dust_201806['[제주 서귀포시]성산읍']+dust_201806['[제주 서귀포시]동홍동']+dust_201806['[제주 제주시]고산리'])/2
dust_201806=dust_201806.set_index('날짜')
dust_201806=dust_201806[['평균']]

# %%
dust_201806=dust_201806.reset_index()

# %%
dust_201806.loc[26,'평균']=dust_201806.loc[26,'평균']*2
dust_201806

# %%
dust_201806=dust_201806.set_index('날짜')
dust_201806

# %%
dust_201807=dust_201807[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201807=dust_201807.fillna(0)
dust_201807['[제주 서귀포시]동홍동']=dust_201807['[제주 서귀포시]동홍동'].astype(int)
dust_201807['[제주 서귀포시]성산읍']=dust_201807['[제주 서귀포시]성산읍'].astype(int)
dust_201807['[제주 제주시]고산리']=dust_201807['[제주 제주시]고산리'].astype(int)
dust_201807=dust_201807.reset_index()

# %%
dust_201807['평균']=(dust_201807['[제주 서귀포시]성산읍']+dust_201807['[제주 서귀포시]동홍동']+dust_201807['[제주 제주시]고산리'])/3

# %%
dust_201807.loc[0,'평균']=dust_201807.loc[0,'평균']*3/2
dust_201807.loc[1,'평균']=dust_201807.loc[1,'평균']*3/2
dust_201807.loc[2,'평균']=dust_201807.loc[2,'평균']*3/2

# %%
dust_201807=dust_201807.set_index('날짜')
dust_201807=dust_201807[['평균']]
dust_201807

# %%
dust_201808=dust_201808[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201808=dust_201808.fillna(0)
dust_201808['[제주 서귀포시]동홍동']=dust_201808['[제주 서귀포시]동홍동'].astype(int)
dust_201808['[제주 서귀포시]성산읍']=dust_201808['[제주 서귀포시]성산읍'].astype(int)
dust_201808['[제주 제주시]고산리']=dust_201808['[제주 제주시]고산리'].astype(int)
dust_201808=dust_201808.reset_index()
dust_201808

# %%
dust_201808.loc[21,'[제주 서귀포시]동홍동']=dust_201808.loc[21,'[제주 제주시]고산리']
dust_201808.loc[21,'[제주 서귀포시]성산읍']=dust_201808.loc[21,'[제주 제주시]고산리']
dust_201808.loc[22,'[제주 서귀포시]동홍동']=dust_201808.loc[22,'[제주 제주시]고산리']
dust_201808.loc[22,'[제주 서귀포시]성산읍']=dust_201808.loc[22,'[제주 제주시]고산리']
dust_201808.loc[23,'[제주 제주시]고산리']=(dust_201808.loc[23,'[제주 서귀포시]동홍동']+dust_201808.loc[23,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[24,'[제주 제주시]고산리']=(dust_201808.loc[24,'[제주 서귀포시]동홍동']+dust_201808.loc[24,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[25,'[제주 제주시]고산리']=(dust_201808.loc[25,'[제주 서귀포시]동홍동']+dust_201808.loc[25,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[26,'[제주 제주시]고산리']=(dust_201808.loc[26,'[제주 서귀포시]동홍동']+dust_201808.loc[26,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[27,'[제주 제주시]고산리']=(dust_201808.loc[27,'[제주 서귀포시]동홍동']+dust_201808.loc[27,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[28,'[제주 제주시]고산리']=(dust_201808.loc[28,'[제주 서귀포시]동홍동']+dust_201808.loc[28,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[29,'[제주 제주시]고산리']=(dust_201808.loc[29,'[제주 서귀포시]동홍동']+dust_201808.loc[29,'[제주 서귀포시]성산읍'])/2
dust_201808.loc[30,'[제주 제주시]고산리']=(dust_201808.loc[30,'[제주 서귀포시]동홍동']+dust_201808.loc[30,'[제주 서귀포시]성산읍'])/2
dust_201808['평균']=(dust_201808['[제주 서귀포시]성산읍']+dust_201808['[제주 서귀포시]동홍동']+dust_201808['[제주 제주시]고산리'])/3
dust_201808=dust_201808.set_index('날짜')
dust_201808=dust_201808[['평균']]
dust_201808

# %%
dust_201809=dust_201809[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201809['[제주 제주시]고산리']=dust_201809['[제주 제주시]고산리'].fillna(0)
dust_201809['[제주 제주시]고산리']=dust_201809['[제주 제주시]고산리'].astype(int)
dust_201809['[제주 서귀포시]동홍동']=dust_201809['[제주 서귀포시]동홍동'].astype(int)
dust_201809['[제주 서귀포시]성산읍']=dust_201809['[제주 서귀포시]성산읍'].astype(int)
dust_201809['평균']=(dust_201809['[제주 서귀포시]성산읍']+dust_201809['[제주 서귀포시]동홍동']+dust_201809['[제주 제주시]고산리'])/2
dust_201809=dust_201809[['평균']]
dust_201809

# %%
dust_201810=dust_201810[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201810=dust_201810[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201810['[제주 제주시]고산리']=dust_201810['[제주 제주시]고산리'].fillna(0)
dust_201810['[제주 제주시]고산리']=dust_201810['[제주 제주시]고산리'].astype(int)
dust_201810['[제주 서귀포시]동홍동']=dust_201810['[제주 서귀포시]동홍동'].astype(int)
dust_201810['[제주 서귀포시]성산읍']=dust_201810['[제주 서귀포시]성산읍'].astype(int)
dust_201810['평균']=(dust_201810['[제주 서귀포시]성산읍']+dust_201810['[제주 서귀포시]동홍동']+dust_201810['[제주 제주시]고산리'])/2
dust_201810=dust_201810[['평균']]
dust_201810

# %%
dust_201811=dust_201811[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201811['[제주 제주시]고산리']=dust_201811['[제주 제주시]고산리'].fillna(0)
dust_201811['[제주 제주시]고산리']=dust_201811['[제주 제주시]고산리'].astype(int)
dust_201811['[제주 서귀포시]동홍동']=dust_201811['[제주 서귀포시]동홍동'].astype(int)
dust_201811['[제주 서귀포시]성산읍']=dust_201811['[제주 서귀포시]성산읍'].astype(int)
dust_201811['평균']=(dust_201811['[제주 서귀포시]성산읍']+dust_201811['[제주 서귀포시]동홍동']+dust_201811['[제주 제주시]고산리'])/2
dust_201811=dust_201811[['평균']]
dust_201811

# %%
dust_201812=dust_201812[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201812['[제주 제주시]고산리']=dust_201812['[제주 제주시]고산리'].fillna(0)
dust_201812['[제주 제주시]고산리']=dust_201812['[제주 제주시]고산리'].astype(int)
dust_201812['[제주 서귀포시]동홍동']=dust_201812['[제주 서귀포시]동홍동'].astype(int)
dust_201812['[제주 서귀포시]성산읍']=dust_201812['[제주 서귀포시]성산읍'].astype(int)
dust_201812['평균']=(dust_201812['[제주 서귀포시]성산읍']+dust_201812['[제주 서귀포시]동홍동']+dust_201812['[제주 제주시]고산리'])/2
dust_201812=dust_201812[['평균']]
dust_201812

# %%
dust_201901=dust_201901[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201901['[제주 제주시]고산리']=dust_201901['[제주 제주시]고산리'].astype(int)
dust_201901['[제주 서귀포시]동홍동']=dust_201901['[제주 서귀포시]동홍동'].astype(int)
dust_201901['[제주 서귀포시]성산읍']=dust_201901['[제주 서귀포시]성산읍'].astype(int)
dust_201901['평균']=(dust_201901['[제주 서귀포시]성산읍']+dust_201901['[제주 서귀포시]동홍동']+dust_201901['[제주 제주시]고산리'])/3
dust_201901=dust_201901[['평균']]
dust_201901

# %%
dust_201902=dust_201902[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201902['[제주 제주시]고산리']=dust_201902['[제주 제주시]고산리'].astype(int)
dust_201902['[제주 서귀포시]동홍동']=dust_201902['[제주 서귀포시]동홍동'].astype(int)
dust_201902['[제주 서귀포시]성산읍']=dust_201902['[제주 서귀포시]성산읍'].astype(int)
dust_201902['평균']=(dust_201902['[제주 서귀포시]성산읍']+dust_201902['[제주 서귀포시]동홍동']+dust_201902['[제주 제주시]고산리'])/3
dust_201902=dust_201902[['평균']]
dust_201902

# %%
dust_201903=dust_201903[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201903['[제주 제주시]고산리']=dust_201903['[제주 제주시]고산리'].astype(int)
dust_201903['[제주 서귀포시]동홍동']=dust_201903['[제주 서귀포시]동홍동'].astype(int)
dust_201903['[제주 서귀포시]성산읍']=dust_201903['[제주 서귀포시]성산읍'].astype(int)
dust_201903['평균']=(dust_201903['[제주 서귀포시]성산읍']+dust_201903['[제주 서귀포시]동홍동']+dust_201903['[제주 제주시]고산리'])/3
dust_201903=dust_201903[['평균']]
dust_201903

# %%
dust_201904=dust_201904[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201904=dust_201904.fillna(0)
dust_201904['[제주 제주시]고산리']=dust_201904['[제주 제주시]고산리'].astype(int)
dust_201904['[제주 서귀포시]동홍동']=dust_201904['[제주 서귀포시]동홍동'].astype(int)
dust_201904['[제주 서귀포시]성산읍']=dust_201904['[제주 서귀포시]성산읍'].astype(int)
dust_201904=dust_201904.reset_index()
dust_201904.loc[22,'[제주 제주시]고산리']=(dust_201904.loc[22,'[제주 서귀포시]동홍동']+dust_201904.loc[22,'[제주 서귀포시]성산읍'])/2
dust_201904.loc[23,'[제주 서귀포시]동홍동']=(dust_201904.loc[23,'[제주 서귀포시]성산읍']+dust_201904.loc[23,'[제주 제주시]고산리'])/2
dust_201904['평균']=(dust_201904['[제주 서귀포시]성산읍']+dust_201904['[제주 서귀포시]동홍동']+dust_201904['[제주 제주시]고산리'])/3
dust_201904=dust_201904.set_index('날짜')
dust_201904=dust_201904[['평균']]
dust_201904

# %%
dust_201905=dust_201905[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201905=dust_201905.fillna(0)
dust_201905['[제주 제주시]고산리']=dust_201905['[제주 제주시]고산리'].astype(int)
dust_201905['[제주 서귀포시]동홍동']=dust_201905['[제주 서귀포시]동홍동'].astype(int)
dust_201905['[제주 서귀포시]성산읍']=dust_201905['[제주 서귀포시]성산읍'].astype(int)
dust_201905=dust_201905.reset_index()
dust_201905.loc[8,'[제주 서귀포시]성산읍']=(dust_201905.loc[8,'[제주 서귀포시]동홍동']+dust_201905.loc[8,'[제주 제주시]고산리'])/2
dust_201905['평균']=(dust_201905['[제주 서귀포시]성산읍']+dust_201905['[제주 서귀포시]동홍동']+dust_201905['[제주 제주시]고산리'])/3
dust_201905=dust_201905.set_index('날짜')
dust_201905=dust_201905[['평균']]
dust_201905

# %%
dust_201906=dust_201906[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201906=dust_201906.fillna(0)
dust_201906['[제주 제주시]고산리']=dust_201906['[제주 제주시]고산리'].astype(int)
dust_201906['[제주 서귀포시]동홍동']=dust_201906['[제주 서귀포시]동홍동'].astype(int)
dust_201906['[제주 서귀포시]성산읍']=dust_201906['[제주 서귀포시]성산읍'].astype(int)
dust_201906=dust_201906.reset_index()
dust_201906.loc[1,'[제주 제주시]고산리']=(dust_201906.loc[1,'[제주 서귀포시]동홍동']+dust_201906.loc[1,'[제주 서귀포시]성산읍'])/2
dust_201906['평균']=(dust_201906['[제주 서귀포시]성산읍']+dust_201906['[제주 서귀포시]동홍동']+dust_201906['[제주 제주시]고산리'])/3
dust_201906=dust_201906.set_index('날짜')
dust_201906=dust_201906[['평균']]
dust_201906

# %%
dust_201907=dust_201907[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201907=dust_201907.fillna(0)
dust_201907['[제주 제주시]고산리']=dust_201907['[제주 제주시]고산리'].astype(int)
dust_201907['[제주 서귀포시]동홍동']=dust_201907['[제주 서귀포시]동홍동'].astype(int)
dust_201907['[제주 서귀포시]성산읍']=dust_201907['[제주 서귀포시]성산읍'].astype(int)
dust_201907=dust_201907.reset_index()
dust_201907.loc[19,'[제주 제주시]고산리']=(dust_201907.loc[19,'[제주 서귀포시]동홍동']+dust_201907.loc[19,'[제주 서귀포시]성산읍'])/2
dust_201907.loc[20,'[제주 제주시]고산리']=(dust_201907.loc[20,'[제주 서귀포시]동홍동']+dust_201907.loc[20,'[제주 서귀포시]성산읍'])/2
dust_201907.loc[30,'[제주 서귀포시]성산읍']=(dust_201907.loc[30,'[제주 서귀포시]동홍동']+dust_201907.loc[30,'[제주 제주시]고산리'])/2

dust_201907['평균']=(dust_201907['[제주 서귀포시]성산읍']+dust_201907['[제주 서귀포시]동홍동']+dust_201907['[제주 제주시]고산리'])/3
dust_201907=dust_201907.set_index('날짜')
dust_201907=dust_201907[['평균']]
dust_201907

# %%
dust_201908=dust_201908[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201908['[제주 제주시]고산리']=dust_201908['[제주 제주시]고산리'].astype(int)
dust_201908['[제주 서귀포시]동홍동']=dust_201908['[제주 서귀포시]동홍동'].astype(int)
dust_201908['[제주 서귀포시]성산읍']=dust_201908['[제주 서귀포시]성산읍'].astype(int)
dust_201908['평균']=(dust_201908['[제주 서귀포시]성산읍']+dust_201908['[제주 서귀포시]동홍동']+dust_201908['[제주 제주시]고산리'])/3
dust_201908=dust_201908[['평균']]
dust_201908

# %%
dust_201909=dust_201909[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201909=dust_201909.fillna(0)
dust_201909['[제주 서귀포시]동홍동']=dust_201909['[제주 서귀포시]동홍동'].astype(int)
dust_201909['[제주 서귀포시]성산읍']=dust_201909['[제주 서귀포시]성산읍'].astype(int)
dust_201909['[제주 제주시]고산리']=dust_201909['[제주 제주시]고산리'].astype(int)
dust_201909=dust_201909.reset_index()

# %%
dust_201909['평균']=(dust_201909['[제주 서귀포시]성산읍']+dust_201909['[제주 서귀포시]동홍동']+dust_201909['[제주 제주시]고산리'])/3
dust_201909.loc[8,'평균']=25.5
dust_201909.loc[13,'평균']=21.5
dust_201909.loc[14,'평균']=23
dust_201909.loc[21,'평균']=20.5
dust_201909

# %%
dust_201909.loc[5,'평균']=19.33333
dust_201909.loc[6,'평균']=22
dust_201909.loc[7,'평균']=25.50000
dust_201909=dust_201909.set_index('날짜')
dust_201909=dust_201909[['평균']]
dust_201909

# %%
dust_201910=dust_201910[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201910=dust_201910.fillna(0)
dust_201910['[제주 서귀포시]동홍동']=dust_201910['[제주 서귀포시]동홍동'].astype(int)
dust_201910['[제주 서귀포시]성산읍']=dust_201910['[제주 서귀포시]성산읍'].astype(int)
dust_201910['[제주 제주시]고산리']=dust_201910['[제주 제주시]고산리'].astype(int)
dust_201910=dust_201910.reset_index()

# %%
dust_201910['평균']=(dust_201910['[제주 서귀포시]성산읍']+dust_201910['[제주 서귀포시]동홍동']+dust_201910['[제주 제주시]고산리'])/3
dust_201910.loc[0,'평균']=21
dust_201910.loc[1,'평균']=21
dust_201910.loc[2,'평균']=21
dust_201910=dust_201910.set_index('날짜')
dust_201910=dust_201910[['평균']]
dust_201910

# %%
dust_201911=dust_201911[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201911=dust_201911.fillna(0)
dust_201911['[제주 서귀포시]동홍동']=dust_201911['[제주 서귀포시]동홍동'].astype(int)
dust_201911['[제주 서귀포시]성산읍']=dust_201911['[제주 서귀포시]성산읍'].astype(int)
dust_201911['[제주 제주시]고산리']=dust_201911['[제주 제주시]고산리'].astype(int)
dust_201911=dust_201911.reset_index()

# %%
dust_201911['평균']=(dust_201911['[제주 서귀포시]성산읍']+dust_201911['[제주 서귀포시]동홍동']+dust_201911['[제주 제주시]고산리'])/3
dust_201911.loc[18,'평균']=38
dust_201911.loc[19,'평균']=22
dust_201911=dust_201911.set_index('날짜')
dust_201911=dust_201911[['평균']]
dust_201911

# %%
dust_201912=dust_201912[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_201912['[제주 제주시]고산리']=dust_201912['[제주 제주시]고산리'].astype(int)
dust_201912['[제주 서귀포시]동홍동']=dust_201912['[제주 서귀포시]동홍동'].astype(int)
dust_201912['[제주 서귀포시]성산읍']=dust_201912['[제주 서귀포시]성산읍'].astype(int)
dust_201912['평균']=(dust_201912['[제주 서귀포시]성산읍']+dust_201912['[제주 서귀포시]동홍동']+dust_201912['[제주 제주시]고산리'])/3
dust_201912=dust_201912[['평균']]
dust_201912

# %%
dust_202001=dust_202001[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202001['[제주 제주시]고산리']=dust_202001['[제주 제주시]고산리'].astype(int)
dust_202001['[제주 서귀포시]동홍동']=dust_202001['[제주 서귀포시]동홍동'].astype(int)
dust_202001['[제주 서귀포시]성산읍']=dust_202001['[제주 서귀포시]성산읍'].astype(int)
dust_202001['평균']=(dust_202001['[제주 서귀포시]성산읍']+dust_202001['[제주 서귀포시]동홍동']+dust_202001['[제주 제주시]고산리'])/3
dust_202001=dust_202001[['평균']]
dust_202001

# %%
dust_202002=dust_202002[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202002['[제주 제주시]고산리']=dust_202002['[제주 제주시]고산리'].astype(int)
dust_202002['[제주 서귀포시]동홍동']=dust_202002['[제주 서귀포시]동홍동'].astype(int)
dust_202002['[제주 서귀포시]성산읍']=dust_202002['[제주 서귀포시]성산읍'].astype(int)
dust_202002['평균']=(dust_202002['[제주 서귀포시]성산읍']+dust_202002['[제주 서귀포시]동홍동']+dust_202002['[제주 제주시]고산리'])/3
dust_202002=dust_202002[['평균']]
dust_202002

# %%
dust_202003=dust_202003[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202003['[제주 제주시]고산리']=dust_202003['[제주 제주시]고산리'].astype(int)
dust_202003['[제주 서귀포시]동홍동']=dust_202003['[제주 서귀포시]동홍동'].astype(int)
dust_202003['[제주 서귀포시]성산읍']=dust_202003['[제주 서귀포시]성산읍'].astype(int)
dust_202003['평균']=(dust_202003['[제주 서귀포시]성산읍']+dust_202003['[제주 서귀포시]동홍동']+dust_202003['[제주 제주시]고산리'])/3
dust_202003=dust_202003[['평균']]
dust_202003

# %%
dust_202004=dust_202004[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202004['[제주 제주시]고산리']=dust_202004['[제주 제주시]고산리'].astype(int)
dust_202004['[제주 서귀포시]동홍동']=dust_202004['[제주 서귀포시]동홍동'].astype(int)
dust_202004['[제주 서귀포시]성산읍']=dust_202004['[제주 서귀포시]성산읍'].astype(int)
dust_202004['평균']=(dust_202004['[제주 서귀포시]성산읍']+dust_202004['[제주 서귀포시]동홍동']+dust_202004['[제주 제주시]고산리'])/3
dust_202004=dust_202004[['평균']]
dust_202004

# %%
dust_202005=dust_202005[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202005=dust_202005.fillna(0)
dust_202005['[제주 서귀포시]동홍동']=dust_202005['[제주 서귀포시]동홍동'].astype(int)
dust_202005['[제주 서귀포시]성산읍']=dust_202005['[제주 서귀포시]성산읍'].astype(int)
dust_202005['[제주 제주시]고산리']=dust_202005['[제주 제주시]고산리'].astype(int)
dust_202005=dust_202005.reset_index()

# %%
dust_202005['평균']=(dust_202005['[제주 서귀포시]성산읍']+dust_202005['[제주 서귀포시]동홍동']+dust_202005['[제주 제주시]고산리'])/3
dust_202005

# %%
dust_202005.loc[16,'평균']=33
dust_202005=dust_202005.set_index('날짜')
dust_202005=dust_202005[['평균']]
dust_202005

# %%
dust_202006=dust_202006[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202006=dust_202006.fillna(0)
dust_202006['[제주 서귀포시]동홍동']=dust_202006['[제주 서귀포시]동홍동'].astype(int)
dust_202006['[제주 서귀포시]성산읍']=dust_202006['[제주 서귀포시]성산읍'].astype(int)
dust_202006['[제주 제주시]고산리']=dust_202006['[제주 제주시]고산리'].astype(int)
dust_202006=dust_202006.reset_index()

# %%
dust_202006['평균']=(dust_202006['[제주 서귀포시]성산읍']+dust_202006['[제주 서귀포시]동홍동']+dust_202006['[제주 제주시]고산리'])/3
dust_202006

# %%
dust_202006.loc[8,'평균']=38
dust_202006=dust_202006.set_index('날짜')
dust_202006=dust_202006[['평균']]
dust_202006

# %%
dust_202007=dust_202007[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202007['[제주 제주시]고산리']=dust_202007['[제주 제주시]고산리'].astype(int)
dust_202007['[제주 서귀포시]동홍동']=dust_202007['[제주 서귀포시]동홍동'].astype(int)
dust_202007['[제주 서귀포시]성산읍']=dust_202007['[제주 서귀포시]성산읍'].astype(int)
dust_202007['평균']=(dust_202007['[제주 서귀포시]성산읍']+dust_202007['[제주 서귀포시]동홍동']+dust_202007['[제주 제주시]고산리'])/3
dust_202007=dust_202007[['평균']]
dust_202007

# %%
dust_202008=dust_202008[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202008=dust_202008.fillna(0)
dust_202008['[제주 서귀포시]동홍동']=dust_202008['[제주 서귀포시]동홍동'].astype(int)
dust_202008['[제주 서귀포시]성산읍']=dust_202008['[제주 서귀포시]성산읍'].astype(int)
dust_202008['[제주 제주시]고산리']=dust_202008['[제주 제주시]고산리'].astype(int)
dust_202008=dust_202008.reset_index()
dust_202008

# %%
dust_202008.loc[26,'[제주 제주시]고산리']=(dust_202008.loc[26,'[제주 서귀포시]동홍동']+dust_202008.loc[26,'[제주 서귀포시]성산읍'])/2
dust_202008.loc[27,'[제주 제주시]고산리']=(dust_202008.loc[27,'[제주 서귀포시]동홍동']+dust_202008.loc[27,'[제주 서귀포시]성산읍'])/2
dust_202008['평균']=(dust_202008['[제주 서귀포시]성산읍']+dust_202008['[제주 서귀포시]동홍동']+dust_202008['[제주 제주시]고산리'])/3
dust_202008

# %%
dust_202008.loc[25,'평균']=27.5
dust_202008=dust_202008.set_index('날짜')
dust_202008=dust_202008[['평균']]
dust_202008

# %%
dust_202009=dust_202009[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202009=dust_202009.fillna(0)
dust_202009['[제주 서귀포시]동홍동']=dust_202009['[제주 서귀포시]동홍동'].astype(int)
dust_202009['[제주 서귀포시]성산읍']=dust_202009['[제주 서귀포시]성산읍'].astype(int)
dust_202009['[제주 제주시]고산리']=dust_202009['[제주 제주시]고산리'].astype(int)
dust_202009=dust_202009.reset_index()
dust_202009

# %%
dust_202009.loc[2,'[제주 제주시]고산리']=(dust_202009.loc[2,'[제주 서귀포시]동홍동']+dust_202009.loc[2,'[제주 서귀포시]성산읍'])/2
dust_202009.loc[3,'[제주 제주시]고산리']=(dust_202009.loc[3,'[제주 서귀포시]동홍동']+dust_202009.loc[3,'[제주 서귀포시]성산읍'])/2
dust_202009.loc[4,'[제주 제주시]고산리']=(dust_202009.loc[4,'[제주 서귀포시]동홍동']+dust_202009.loc[4,'[제주 서귀포시]성산읍'])/2
dust_202009.loc[5,'[제주 제주시]고산리']=(dust_202009.loc[5,'[제주 서귀포시]동홍동']+dust_202009.loc[5,'[제주 서귀포시]성산읍'])/2
dust_202009.loc[6,'[제주 제주시]고산리']=(dust_202009.loc[6,'[제주 서귀포시]동홍동']+dust_202009.loc[6,'[제주 서귀포시]성산읍'])/2
dust_202009['평균']=(dust_202009['[제주 서귀포시]성산읍']+dust_202009['[제주 서귀포시]동홍동']+dust_202009['[제주 제주시]고산리'])/3
dust_202009=dust_202009.set_index('날짜')
dust_202009=dust_202009[['평균']]
dust_202009

# %%
dust_202009=dust_202009.reset_index()
dust_202009

# %%
dust_202009.loc[1,'평균']=28
dust_202009=dust_202009.set_index('날짜')
dust_202009=dust_202009[['평균']]
dust_202009

# %%
dust_202010=dust_202010[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202010['[제주 제주시]고산리']=dust_202010['[제주 제주시]고산리'].astype(int)
dust_202010['[제주 서귀포시]동홍동']=dust_202010['[제주 서귀포시]동홍동'].astype(int)
dust_202010['[제주 서귀포시]성산읍']=dust_202010['[제주 서귀포시]성산읍'].astype(int)
dust_202010['평균']=(dust_202010['[제주 서귀포시]성산읍']+dust_202010['[제주 서귀포시]동홍동']+dust_202010['[제주 제주시]고산리'])/3
dust_202010=dust_202010[['평균']]
dust_202010

# %%
dust_202011=dust_202011[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202011['[제주 제주시]고산리']=dust_202011['[제주 제주시]고산리'].astype(int)
dust_202011['[제주 서귀포시]동홍동']=dust_202011['[제주 서귀포시]동홍동'].astype(int)
dust_202011['[제주 서귀포시]성산읍']=dust_202011['[제주 서귀포시]성산읍'].astype(int)
dust_202011['평균']=(dust_202011['[제주 서귀포시]성산읍']+dust_202011['[제주 서귀포시]동홍동']+dust_202011['[제주 제주시]고산리'])/3
dust_202011=dust_202011[['평균']]
dust_202011

# %%
dust_202012=dust_202012[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202012['[제주 제주시]고산리']=dust_202012['[제주 제주시]고산리'].astype(int)
dust_202012['[제주 서귀포시]동홍동']=dust_202012['[제주 서귀포시]동홍동'].astype(int)
dust_202012['[제주 서귀포시]성산읍']=dust_202012['[제주 서귀포시]성산읍'].astype(int)
dust_202012['평균']=(dust_202012['[제주 서귀포시]성산읍']+dust_202012['[제주 서귀포시]동홍동']+dust_202012['[제주 제주시]고산리'])/3
dust_202012=dust_202012[['평균']]
dust_202012

# %%
dust_202101=dust_202101[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202101['[제주 제주시]고산리']=dust_202101['[제주 제주시]고산리'].astype(int)
dust_202101['[제주 서귀포시]동홍동']=dust_202101['[제주 서귀포시]동홍동'].astype(int)
dust_202101['[제주 서귀포시]성산읍']=dust_202101['[제주 서귀포시]성산읍'].astype(int)
dust_202101['평균']=(dust_202101['[제주 서귀포시]성산읍']+dust_202101['[제주 서귀포시]동홍동']+dust_202101['[제주 제주시]고산리'])/3
dust_202101=dust_202101[['평균']]
dust_202101

# %%
dust_202102=dust_202102[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202102['[제주 제주시]고산리']=dust_202102['[제주 제주시]고산리'].astype(int)
dust_202102['[제주 서귀포시]동홍동']=dust_202102['[제주 서귀포시]동홍동'].astype(int)
dust_202102['[제주 서귀포시]성산읍']=dust_202102['[제주 서귀포시]성산읍'].astype(int)
dust_202102['평균']=(dust_202102['[제주 서귀포시]성산읍']+dust_202102['[제주 서귀포시]동홍동']+dust_202102['[제주 제주시]고산리'])/3
dust_202102=dust_202102[['평균']]
dust_202102

# %%
dust_202103=dust_202103[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202103=dust_202103.fillna(0)
dust_202103['[제주 서귀포시]동홍동']=dust_202103['[제주 서귀포시]동홍동'].astype(int)
dust_202103['[제주 서귀포시]성산읍']=dust_202103['[제주 서귀포시]성산읍'].astype(int)
dust_202103['[제주 제주시]고산리']=dust_202103['[제주 제주시]고산리'].astype(int)
dust_202103=dust_202103.reset_index()
dust_202103

# %%
dust_202103.loc[29,'[제주 제주시]고산리']=(dust_202103.loc[29,'[제주 서귀포시]동홍동']+dust_202103.loc[29,'[제주 서귀포시]성산읍'])/2
dust_202103['평균']=(dust_202103['[제주 서귀포시]성산읍']+dust_202103['[제주 서귀포시]동홍동']+dust_202103['[제주 제주시]고산리'])/3
dust_202103=dust_202103.set_index('날짜')
dust_202103=dust_202103[['평균']]
dust_202103

# %%
dust_202104=dust_202104[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202104=dust_202104.fillna(0)
dust_202104['[제주 서귀포시]동홍동']=dust_202104['[제주 서귀포시]동홍동'].astype(int)
dust_202104['[제주 서귀포시]성산읍']=dust_202104['[제주 서귀포시]성산읍'].astype(int)
dust_202104['[제주 제주시]고산리']=dust_202104['[제주 제주시]고산리'].astype(int)
dust_202104=dust_202104.reset_index()
dust_202104

# %%
dust_202104.loc[4,'[제주 제주시]고산리']=(dust_202104.loc[4,'[제주 서귀포시]동홍동']+dust_202104.loc[4,'[제주 서귀포시]성산읍'])/2
dust_202104['평균']=(dust_202104['[제주 서귀포시]성산읍']+dust_202104['[제주 서귀포시]동홍동']+dust_202104['[제주 제주시]고산리'])/3
dust_202104=dust_202104.set_index('날짜')
dust_202104=dust_202104[['평균']]
dust_202104

# %%
dust_202105=dust_202105[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202105['[제주 제주시]고산리']=dust_202105['[제주 제주시]고산리'].astype(int)
dust_202105['[제주 서귀포시]동홍동']=dust_202105['[제주 서귀포시]동홍동'].astype(int)
dust_202105['[제주 서귀포시]성산읍']=dust_202105['[제주 서귀포시]성산읍'].astype(int)
dust_202105['평균']=(dust_202105['[제주 서귀포시]성산읍']+dust_202105['[제주 서귀포시]동홍동']+dust_202105['[제주 제주시]고산리'])/3
dust_202105=dust_202105[['평균']]
dust_202105

# %%
dust_202106=dust_202106[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202106=dust_202106.fillna(0)
dust_202106['[제주 서귀포시]동홍동']=dust_202106['[제주 서귀포시]동홍동'].astype(int)
dust_202106['[제주 서귀포시]성산읍']=dust_202106['[제주 서귀포시]성산읍'].astype(int)
dust_202106['[제주 제주시]고산리']=dust_202106['[제주 제주시]고산리'].astype(int)
dust_202106=dust_202106.reset_index()

# %%
dust_202106.loc[10,'[제주 제주시]고산리']=(dust_202106.loc[10,'[제주 서귀포시]동홍동']+dust_202106.loc[10,'[제주 서귀포시]성산읍'])/2
dust_202106.loc[11,'[제주 제주시]고산리']=(dust_202106.loc[11,'[제주 서귀포시]동홍동']+dust_202106.loc[11,'[제주 서귀포시]성산읍'])/2
dust_202106['평균']=(dust_202106['[제주 서귀포시]성산읍']+dust_202106['[제주 서귀포시]동홍동']+dust_202106['[제주 제주시]고산리'])/3
dust_202106=dust_202106.set_index('날짜')
dust_202106=dust_202106[['평균']]
dust_202106

# %%
result=pd.concat([dust_202106,dust_202105,dust_202104,dust_202103,dust_202102,dust_202101,dust_202012,dust_202011,dust_202010,dust_202010,dust_202009,dust_202008,dust_202007,dust_202006,dust_202005,dust_202004,dust_202003,dust_202002,dust_202001,dust_201912,dust_201911,dust_201910,dust_201909,dust_201908,dust_201907,dust_201906,dust_201905,dust_201904,dust_201903,dust_201902,dust_201901,dust_201812,dust_201811,dust_201810,dust_201809,dust_201808,dust_201807,dust_201806,dust_201805,dust_201804])
result

# %%
result.to_csv("미세먼지.csv",encoding='cp949')

# %%
dust_all= pd.read_csv('C:/Users/82109/Downloads/미세먼지.csv',encoding='cp949')
dust_all

# %%
def make_year(i):
    i=i.split('년')[0]
    return i
def make_month(i):
    i=i.split('월')[0][-2:]
    return i
def make_day(i):
    i=i.split('일')[0][-2:]
    return i

# %%
dust_all['연월일시']=dust_all['날짜']
dust_all['연']=dust_all['날짜'].map(lambda x: make_year(x))
dust_all['월']=dust_all['날짜'].map(lambda x: make_month(x))
dust_all['일']=dust_all['날짜'].map(lambda x: make_day(x))
dust_all['date']=dust_all['연']+"-"+dust_all['월']+"-"+dust_all['일']

# %%
dust_all=dust_all[['date','평균']]

# %%
dust_all.to_csv("미세먼지_clean.csv",encoding='cp949')

# %%
dust_all= pd.read_csv('C:/Users/82109/Downloads/미세먼지_clean.csv',encoding='cp949')
dust_all

# %%
#------------------

# %%
dust_202107= pd.read_csv('C:/Users/82109/Downloads/2021_07.CSV',encoding='euc-kr')
dust_202107 = dust_202107.drop([0], axis=0)
dust_202107= dust_202107.drop([7], axis=0)
dust_202107=dust_202107.transpose()
dust_202107=dust_202107.set_index(1)
dust_202107 = dust_202107.drop(['측정망'], axis=0)
dust_202107=dust_202107.transpose()
dust_202107=dust_202107.set_index('측정소명')
dust_202107=dust_202107.transpose()
dust_202107=dust_202107.reset_index()
dust_202107['날짜']='2021년 7월'+dust_202107[1]
dust_202107=dust_202107[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','날짜']]
dust_202107=dust_202107.set_index('날짜')
dust_202107=dust_202107[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202107['[제주 제주시]고산리']=dust_202107['[제주 제주시]고산리'].astype(int)
dust_202107['[제주 서귀포시]동홍동']=dust_202107['[제주 서귀포시]동홍동'].astype(int)
dust_202107['[제주 서귀포시]성산읍']=dust_202107['[제주 서귀포시]성산읍'].astype(int)
dust_202107['평균']=(dust_202107['[제주 서귀포시]성산읍']+dust_202107['[제주 서귀포시]동홍동']+dust_202107['[제주 제주시]고산리'])/3
dust_202107=dust_202107[['평균']]
dust_202107

# %%
dust_202108= pd.read_csv('C:/Users/82109/Downloads/2021_08.CSV',encoding='euc-kr')
dust_202108 = dust_202108.drop([0], axis=0)
dust_202108= dust_202108.drop([7], axis=0)
dust_202108=dust_202108.transpose()
dust_202108=dust_202108.set_index(1)
dust_202108 = dust_202108.drop(['측정망'], axis=0)
dust_202108=dust_202108.transpose()
dust_202108=dust_202108.set_index('측정소명')
dust_202108=dust_202108.transpose()
dust_202108=dust_202108.reset_index()
dust_202108['날짜']='2021년 8월'+dust_202108[1]
dust_202108=dust_202108[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍','날짜']]
dust_202108=dust_202108.set_index('날짜')
dust_202108=dust_202108[['[제주 제주시]고산리','[제주 서귀포시]동홍동','[제주 서귀포시]성산읍']]
dust_202108['[제주 제주시]고산리']=dust_202108['[제주 제주시]고산리'].astype(int)
dust_202108['[제주 서귀포시]동홍동']=dust_202108['[제주 서귀포시]동홍동'].astype(int)
dust_202108['[제주 서귀포시]성산읍']=dust_202108['[제주 서귀포시]성산읍'].astype(int)
dust_202108['평균']=(dust_202108['[제주 서귀포시]성산읍']+dust_202108['[제주 서귀포시]동홍동']+dust_202108['[제주 제주시]고산리'])/3
dust_202108=dust_202108[['평균']]
dust_202108

# %%
dust_202107=dust_202107.reset_index()
dust_202107

# %%
dust_202108=dust_202108.reset_index()
dust_202108

# %%
dust_all=pd.concat([dust_202108,dust_202107])
dust_all

# %%
dust_all['연월일시']=dust_all['날짜']
dust_all['연']=dust_all['날짜'].map(lambda x: make_year(x))
dust_all['월']=dust_all['날짜'].map(lambda x: make_month(x))
dust_all['일']=dust_all['날짜'].map(lambda x: make_day(x))
dust_all['date']=dust_all['연']+"-"+dust_all['월']+"-"+dust_all['일']

# %%
dust_all=dust_all[['date','평균']]

# %%
dust= pd.read_csv('C:/Users/82109/Downloads/미세먼지_clean.csv',encoding='cp949')
dust

# %%
dust=dust[['date','평균']]
dust

# %%
final=pd.concat([dust_all,dust])
final

# %%
final.to_csv("../data/외부데이터/미세먼지_final.csv",encoding='cp949')

# %%
dust_all= pd.read_csv('../data/외부데이터/미세먼지_final.csv',encoding='cp949')
dust_all

# %%
dust_all['date'].replace('월','0')

# %%
def month(i):
    i=i.split('-')[1]
    return i

# %%
def year(i):
    i=i.split('-')[0]
    return i

# %%
dust_all['월']=dust_all['date'].map(lambda x: month(x))
dust_all

# %%
dust_all['연도']=dust_all['date'].map(lambda x: year(x))
dust_all

# %%
def change(i):
    i=i.replace('월','0')
    return i

dust_all['일']=dust_all['date'].map(lambda x: change(x))
dust_all

# %%
dust_all['날짜']=dust_all['연도']+"-"+dust_all['월']

# %%
dust_month=dust_all.groupby('날짜').mean()
dust_month=dust_month[['평균']]
dust_month

# %%
dust_month.to_csv("../data/외부데이터/dust_mean_final.csv",encoding='cp949')
